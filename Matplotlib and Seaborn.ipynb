# %%
pandas, matplotlib, seaborn.

# %%
The kind of plot to produce:

       kind= - 'line' : line plot (default)
        - 'bar' : vertical bar plot
        - 'barh' : horizontal bar plot
        - 'hist' : histogram
        - 'box' : boxplot
        - 'kde' : Kernel Density Estimation plot
        - 'density' : same as 'kde'
        - 'area' : area plot
        - 'pie' : pie plot
        - 'scatter' : scatter plot (DataFrame only)
        - 'hexbin' : hexbin plot (DataFrame only)

# %%
import pandas as pd
df = pd.read_csv(r"D:\DS-Batch1\DS dataset\Salaries.csv")
df.head(3)
# Out:
#         rank discipline  phd  service     sex  salary
# 0       Prof          A   51       51    Male   57800
# 1  AssocProf          A   25       22  Female   62884
# 2   AsstProf          A    7        6  Female   63100

# %%
age = [23,22,23,22,22,24,21,22,22,22,22,22,22,22,22,24,31,22,21,20,24,24,21,32,19]
min(age),max(age),len(age)
# Out:
# (19, 32, 25)

# %%
import pandas as pd
age = pd.Series(age)

# %%
age.value_counts()
# Out:
# 22    12
# 24     4
# 21     3
# 23     2
# 31     1
# 20     1
# 32     1
# 19     1
# Name: count, dtype: int64

# %%
Q1 = age.quantile(0.25)
Q2 = age.quantile(0.50)
Q3 = age.quantile(0.75)
QD = Q3-Q1
IQR = [Q1-1.5*QD,Q3+1.5*QD ]

# %%
IQR
# Out:
# [20.5, 24.5]

# %%
age.plot(kind = 'box')
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %% [markdown]
# # Scatter plot

# %%
df.plot(kind = 'scatter', x = 'salary', y = 'service')
# Out:
# <Axes: xlabel='salary', ylabel='service'>

# %%
df['salary'].corr(df['service'])
# Out:
# 0.5321913486037867

# %%
df['service'].values
# Out:
# array([51, 22,  6,  9,  0,  1,  2, 24,  3,  3,  8,  3,  0,  8,  2,  3,  2,
#        17,  0,  0, 11,  3, 27, 23,  2,  0,  4,  3,  6, 19,  5, 31,  8, 30,
#        19, 11, 10, 10,  6, 18,  0, 10,  7,  7, 15,  7, 14, 20, 17,  7, 19,
#         8, 18, 20, 18, 20, 17, 18, 23, 14, 33, 18, 31, 23, 36, 25, 26, 45,
#        19,  3, 27, 19, 19, 21, 43, 15, 33, 49], dtype=int64)

# %%
type(df['service'].values)
# Out:
# numpy.ndarray

# %%
import numpy as np
np.corrcoef(df['phd'].values,df['salary'].values)
# Out:
# array([[1.        , 0.58135561],
#        [0.58135561, 1.        ]])

# %% [markdown]
# # line chart

# %%
df['phd']
# Out:
# 0     51
# 1     25
# 2      7
# 3     12
# 4      2
#       ..
# 73    22
# 74    45
# 75    24
# 76    35
# 77    56
# Name: phd, Length: 78, dtype: int64

# %%
df['phd'].plot()
# Out:
# <Axes: >

# %%
df[['phd','service']].plot()
# Out:
# <Axes: >

# %%
df['phd'].plot()
df['service'].plot()
# Out:
# <Axes: >

# %% [markdown]
# # histogram

# %%
df["salary"].plot(kind ='hist',bins = 10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[["phd",'service']].plot(kind = 'hist',bins = 10,alpha = 0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.value_counts()
# Out:
# rank       discipline  phd  service  sex     salary
# AssocProf  A           10   8        Female  77500     1
# Prof       A           36   19       Female  117555    1
#            B           17   17       Female  111512    1
#                             3        Male    150480    1
#            A           51   51       Male    57800     1
#                                                       ..
# AsstProf   B           4    3        Male    91000     1
#                             2        Female  80225     1
#                             0        Male    92000     1
#                        3    3        Female  92000     1
# Prof       B           56   49       Male    186960    1
# Name: count, Length: 78, dtype: int64

# %% [markdown]
# # Bar chart

# %%
Rank_totals = round(df.groupby("sex")['salary'].mean(),2)
print(Rank_totals)
Rank_totals.plot(kind = 'bar')
# Out:
# sex
# Female    101002.41
# Male      115045.15
# Name: salary, dtype: float64
# <Axes: xlabel='sex'>

# %%
Rank_totals.plot(kind = 'barh',color = ['r','y'])
# Out:
# <Axes: ylabel='sex'>

# %%
Rank_totals.plot(kind = 'barh',alpha = 0.6,stacked= True)
# Out:
# <Axes: ylabel='sex'>

# %%
Rank_totals.plot(kind = 'barh',color = ['r','g'],subplots = True)
# Out:
# array([<Axes: title={'center': 'phd'}, ylabel='sex'>,
#        <Axes: title={'center': 'service'}, ylabel='sex'>], dtype=object)

# %% [markdown]
# # pie chart

# %%
Rank_totals.plot(kind = 'pie', subplots = False, figsize = (4,6),rot = 0)
# Out:
# <Axes: ylabel='salary'>

# %%
# Rank_totals.plot.bar(color = ['green','red'],subplots = True,rot = 45)

# %% [markdown]
# # Box chart

# %%
df[['phd','service']].plot(kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# # Area chart

# %%
df[['phd','service']].plot(kind ='area',alpha = 0.5)
# Out:
# <Axes: >

# %% [markdown]
# # KDE plot

# %%
# kernel density estimator plot
df[['service','phd']].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # hexabin plot

# %%
df.plot(kind = 'hexbin',x = 'service', y = 'salary', gridsize=10, figsize=(5,4))
# Out:
# <Axes: xlabel='service', ylabel='salary'>

# %% [markdown]
# # customization
# x and y parameters specify the values that you want on the x and y column. In the above case, these were the Date and the NIFTY Bank index column.
# 1. figsize: specifies the size of the figure object.
# 2. Title: to be used for the plot.
# 3. legend: to be placed on-axis subplots.
# 4. Style: the matplotlib line style per column.
# 5. X and y label: name to use for the label on the x-axis and y-axis.
# 6. Subplots: make separate subplots for each column.
# 7. Kind: the kind of plot to produce.

# %%
df.plot().scatter()

# %%
import pandas as pd
df = pd.read_csv(r"D:\DS-Batch1\DS dataset\Salaries.csv")
df.plot(kind = 'scatter',x = 'service',y='salary',ylim = (50000,180000) ,xlim = (10,55),
        figsize=(8,4),title='Salary and Service infomation',
        ylabel = 'Salary in Rupees',xlabel = 'Service in years',
        marker = 'D',color = 'k');

# %% [markdown]
# # Scatter matrix plot

# %%
Scatter matrix plot
A scatter matrix, as the name suggests, creates a matrix of scatter plots using the \
scatter_matrix method in pandas Plotting.

# %%
df.head()
# Out:
#         rank discipline  phd  service     sex  salary
# 0       Prof          A   51       51    Male   57800
# 1  AssocProf          A   25       22  Female   62884
# 2   AsstProf          A    7        6  Female   63100
# 3  AssocProf          B   12        9  Female   71065
# 4   AsstProf          A    2        0  Female   72500

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize=(10, 6),alpha = 0.5,color = 'k',diagonal = 'kde');

# %%
Bootstrap plot
Bootstrap plots visually assess a statistic’s uncertainty, such as mean, median, midrange, etc. 
Bootstrapping involves calculating a statistic by randomly sampling from the same data multiple times,
and then averaging each sample’s individual result. The resultant values obtained from each random sample are 
then plotted in the form of line and bar charts.

# %%
from pandas.plotting import bootstrap_plot
bootstrap_plot(df['salary'])

# %% [markdown]
# # matplotlib

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv(r"D:\DS-Batch1\DS dataset\Salaries.csv")
df.head(3)
# Out:
#         rank discipline  phd  service     sex  salary
# 0       Prof          A   51       51    Male   57800
# 1  AssocProf          A   25       22  Female   62884
# 2   AsstProf          A    7        6  Female   63100

# %%
plt.bar(x=df['rank'],height = df['service'])
plt.show()

# %%
plt.hist(df[['phd','service']],bins = 5,alpha = 0.7,cumulative=True,
    stacked=True,density=True,orientation='horizontal',histtype = 'stepfilled')
plt.show()

# %%
# Function to plot scatter
plt.scatter(df['salary'],df['service'],s = 50, marker = 'o', c='green')
# function to show the plot
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style

style.use('fivethirtyeight')
# style.use('ggplot')
# style.use('dark_background')
# style.use('grayscale')

#can plot specifically, after just showing the defaults:
# plt.plot(df['service'],linewidth=2, c = 'b')
plt.scatter(x= df['phd'],y= df['salary'], linewidth=2,marker = '*',c = 'y')
plt.plot(df['salary'],linewidth=2, c = 'b')
plt.title('Salary and PHD information')
plt.ylabel('Service in Experience')
plt.xlabel('PHD info')
plt.show()

# %%
plt.plot(df['phd'],'y',label='PHD', linewidth=3,linestyle = '-.')
plt.plot(df['service'],'g',label='Experience',linewidth=3,linestyle = '--')
plt.grid(False, color='b', linestyle='--',linewidth=1.5,axis = 'y')
plt.legend(loc= 'lower right',labelcolor= 'k')
plt.show()
# Out:
# C:\Users\excel\AppData\Local\Temp\ipykernel_10292\3914203638.py:3: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   plt.grid(False, color='b', linestyle='--',linewidth=1.5,axis = 'y')

# %%
Figure class
Figure class is the top-level container that contains one or more axes. 
It is the overall window or page on which everything is drawn.

Syntax:

class matplotlib.figure.Figure(figsize=None, dpi=None, facecolor=None, edgecolor=None, 
                               linewidth=0.0, frameon=None, subplotpars=None, tight_layout=None,
                               constrained_layout=None)

Axes Class
Axes class is the most basic and flexible unit for creating sub-plots. 
A given figure may contain many axes, but a given axes can only be present in one figure. 
The axes() function creates the axes object. Let’s see the below example.

Syntax:

matplotlib.pyplot.axes(*args, emit=True, **kwargs)

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt 
from matplotlib.figure import Figure 
# Creating a new figure with width = 3 inches and height = 2 inches
fig = plt.figure(figsize =(3,2),facecolor='lightskyblue',edgecolor='b') 
# Creating a new axes for the figure
ax = fig.add_axes([1, 3, 2, 3])  
# Adding the data to be plotted
ax.scatter(df['phd'],df['service'])
plt.show()

# %%
# Creating a new axes for the figure
fig = plt.figure(figsize =(1,2)) 
ax = fig.add_axes([2,2,2,2]) 
  
# Adding the data to be plotted
ax.scatter(df['phd'],df['service'])
plt.show()

# %%
'aitoff', 'hammer', 'lambert', 'mollweide', 'polar','3d'

# %%
ax = plt.axes([1, 1, 1 ,1],projection='aitoff')

# %%
import numpy as np
x = np.array([0, 1, 2, 3])
y = np.array([5,4,6,7])
plt.subplot(3, 1, 3)
plt.scatter(x,y)

plt.subplot(3, 1, 1)
plt.hist(x)

plt.subplot(3,1, 2)
plt.plot(x,y)

# plt.subplot(4, 1, 4)
# plt.box(y)

# %%
plt.subplot(2, 3, 1)
plt.scatter(df['phd'],df['salary'])

plt.subplot(2, 3, 2)
plt.bar(df['rank'],height = df['salary'])

plt.subplot(2, 3, 3)
plt.hist(df['salary'])
# Out:
# (array([ 3., 15., 12., 14.,  9., 11.,  4.,  8.,  1.,  1.]),
#  array([ 57800.,  70716.,  83632.,  96548., 109464., 122380., 135296.,
#         148212., 161128., 174044., 186960.]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt 
# Creating the figure object
fig = plt.figure()
# keeping the projection = 3d
# creates the 3d plot
ax = plt.axes(projection = '3d')

# %%
import matplotlib.pyplot as plt 
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]
z = [1, 8, 27, 64, 125]
X = [10,15,8,6,4]
Y = [2,5,6,7,8]
Z = [15,18,100,80,70]
# Creating the figure object
fig = plt.figure()
# keeping the projection = 3d creates the 3d plot
ax = plt.axes(projection = '3d')
ax.bar3d(x,y,z,dx = 5,dy = 5,dz = 50,color = 'r')
ax.scatter3D(X,Y,Z,c = 'g')

# %% [markdown]
# # seaborn library

# %%
Univariate – x only (contains only one axis of information)
Bivariate – x and y (contains two axis of information)
Trivariate – x, y, z (contains three axis of information)

Scatter Plot. A scatter plot is used to visualize the relationship between two variables. 
Seaborn's scatterplot() function provides a simple way to create scatter plots.

Line Plot. A line plot is used to visualize the trend of a variable over time.
Seaborn's lineplot() function provides a simple way to create line plots.

Histogram. A histogram is used to visualize the distribution of a variable. 
Seaborn's histplot() function provides a simple way to create histograms.

Box Plot. A box plot is used to visualize the distribution of a variable. 
Seaborn's boxplot() function provides a simple way to create box plots.

Violin Plot. A violin plot is similar to a box plot, but provides a more detailed view of the distribution of the data.
Seaborn's violinplot() function provides a simple way to create violin plots.

Heatmap. A heatmap is used to visualize the correlation between different variables.
Seaborn's heatmap() function provides a simple way to create heatmaps.

Pairplot. A pairplot is used to visualize the relationship between multiple variables.
Seaborn's pairplot() function provides a simple way to create pairplots.

# %%
# !pip install seaborn --upgrade

# %%
sns.__version__
# Out:
# '0.12.2'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic', 'anagrams', 'anagrams', 'anscombe', 'anscombe', 'attention', 'attention', 'brain_networks', 'brain_networks', 'car_crashes', 'car_crashes', 'diamonds', 'diamonds', 'dots', 'dots', 'dowjones', 'dowjones', 'exercise', 'exercise', 'flights', 'flights', 'fmri', 'fmri', 'geyser', 'geyser', 'glue', 'glue', 'healthexp', 'healthexp', 'iris', 'iris', 'mpg', 'mpg', 'penguins', 'penguins', 'planets', 'planets', 'seaice', 'seaice', 'taxis', 'taxis', 'tips', 'tips', 'titanic', 'titanic', 'anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
tips = sns.load_dataset("tips")
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
tips['total_bill'].corr(tips['tip'])
# Out:
# 0.6757341092113641

# %%
style.use('fivethirtyeight')
# customize the scatter plot
sns.scatterplot(x="total_bill", y="tip" ,hue="time", size="size", sizes=(1,200), data=tips)
# add labels and title
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.title("Relationship between Total Bill and Tip",c='k')
# display the plot
plt.show()

# %%
element : {"bars", "step", "poly"}

# %%
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
pd.option_context('mode.use_inf_as_na', True)
sns.histplot(data=tips,x="tip",stat='density',
             binrange=(1,5),multiple = 'layer',element = 'poly',kde=True)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='tip', ylabel='Density'>

# %%
# create a FacetGrid for day vs total_bill
g = sns.FacetGrid(tips, col="day")
# plot histogram for total_bill in each day
g.map(sns.histplot, "tip")
# Out:
# C:\ProgramData\anaconda3\New folder\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.kdeplot(data=tips, x="total_bill", hue ="day", fill=True, alpha=0.6, linewidth=5)
# Add a title and labels to the plot using Matplotlib
plt.title("Density Plot of Total Bill by Meal Time")
plt.xlabel("Total Bill ($)")
plt.ylabel("Density")
# Show the plot
plt.show()

# %%
sns.boxplot(x="day", y="total_bill", hue="time", data=tips, palette="Set3", linewidth=1.5, fliersize=5)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
fmri = sns.load_dataset("fmri")
print(fmri.head())
print(fmri['region'].value_counts())
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970
# region
# parietal    532
# frontal     532
# Name: count, dtype: int64

# %%
fmri = sns.load_dataset("fmri")
# customize the line plot
sns.lineplot(x="timepoint", y="signal", hue="event", style="region", markers=True, dashes=True, data=fmri)
# add labels and title
plt.xlabel("Timepoint")
plt.ylabel("Signal Intensity")
plt.title("Changes in Signal Intensity over Time")
# display the plot
plt.show()

# %%
titanic = sns.load_dataset("titanic")
print(titanic.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic = sns.load_dataset("titanic")
# customize the bar plot
sns.barplot(x="pclass", y="fare", hue="sex",errorbar = 'ci', palette="bright", data=titanic)
# add labels and title
plt.xlabel("Class")
plt.ylabel("Fare")
plt.title("Average Fare by Class and Gender on the Titanic")
# display the plot
plt.show()

# %%
iris = sns.load_dataset("iris")
print(iris)
print(iris['species'].value_counts())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
sns.kdeplot(x="petal_length", data=iris, label='petal_length')
sns.kdeplot(x="sepal_length", data=iris, label='sepal_length')
sns.kdeplot(x="petal_width", data=iris, label='petal_width')
sns.kdeplot(x="sepal_width", data=iris, label='sepal_width')
plt.legend()

# %%
"point", "stick"

# %%
sns.violinplot(x="species", y="petal_length", data=iris,inner = 'box')
# display the plot
plt.show()

# %%
# Create pair plot
sns.pairplot(data=iris,diag_kind ='kde',kind = 'reg')
# Show plot
plt.show()
# Out:
# C:\ProgramData\anaconda3\New folder\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.jointplot(x="sepal_length", y="sepal_width", data=iris)
plt.show()

# %%
flights = sns.load_dataset('flights')
print(flights.head())
ff = flights.pivot(index='month', columns='year', values='passengers')
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights['year'].value_counts()
# Out:
# year
# 1949    12
# 1950    12
# 1951    12
# 1952    12
# 1953    12
# 1954    12
# 1955    12
# 1956    12
# 1957    12
# 1958    12
# 1959    12
# 1960    12
# Name: count, dtype: int64

# %%
sns.heatmap(ff, cmap='Blues', annot=True, fmt='d')
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
# Load sample dataset
diamonds = sns.load_dataset("diamonds")
print(diamonds.head())
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# Load sample dataset
diamonds = sns.load_dataset("diamonds")
# Create a scatter plot with annotations
sns.scatterplot(x="carat", y="price", data=diamonds)
# Add annotations
plt.text(0.5, 15000, "Large, Expensive Diamonds", fontsize=18, color="red")
plt.text(2.5, 5000, "Small, Affordable Diamonds", fontsize=18, color="black")
# Customize plot
plt.title("Diamond Prices by Carat")
plt.xlabel("Carat (ct)")
plt.ylabel("Price ($)")
plt.show()

# %%
# !pip install seaborn --upgrade

# %%
import sea
sns.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.__version__
#
# NameError: name 'sns' is not defined
